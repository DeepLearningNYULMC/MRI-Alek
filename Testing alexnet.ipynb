# %%
import train_convolution_intermediate_AUC
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-07f87e8831d7> in <module>()
# ----> 1 import train_convolution_intermediate_AUC
#
# /home/ak4966/MRI-Alek/train_convolution_intermediate_AUC.py in <module>()
#      17 import pickle
#      18 import numpy
# ---> 19 import cv2
#      20 numpy.set_printoptions(threshold=numpy.nan)
#      21 import csv
#
# ImportError: No module named 'cv2'

# %%
import train_convolution_intermediate_AUC
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-07f87e8831d7> in <module>()
# ----> 1 import train_convolution_intermediate_AUC
#
# /home/ak4966/MRI-Alek/train_convolution_intermediate_AUC.py in <module>()
#      22 from PIL import Image
#      23 from sklearn.preprocessing import normalize
# ---> 24 from imgaug import augmenters as iaa
#      25 import random
#      26
#
# ImportError: No module named 'imgaug'

# %%
import train_convolution_intermediate_AUC

# %%
cd
# Out:
# /home/ak4966

# %%
ls
# Out:
# get-pip.py         Module.class          random_num_list.txt
# Instruction.class  MRI/                  sortProcessComparator.class
# Lab1.class         MRI-Alek/             Symbol.class
# Lab1.java          nvidia_sdk/           TCGA_id_list.csv
# Lab2.class         perl5/                tensorflow_testing/
# Lab2.java          Process.class         Untitled.ipynb
# Lab2Testing.txt    PSFJComparator.class  Uses.class
# mail@              public_html@

# %%
cd MRI-Alek
# Out:
# /home/ak4966/MRI-Alek

# %%
ls
# Out:
# build_aggregating_validation.py
# build_testing_set_clean.py*
# build_testing_set_save_patientID_no_aggregation.py*
# build_testing_set_save_patientID.py
# build_training_set_clean.py*
# build_training_set_normalization.py
# build_training_set.py
# data_set.py
# group_data.py
# models/
# mri_models_convnet.ipynb
# organize_data.py
# __pycache__/
# pytorch_train.py*
# README.md
# Running alexnet.ipynb
# testing_model_aggregating_normalization.py
# testing_model_aggregating.py
# testing_model_all_modalities.py
# testing_model.py
# train_convolution_intermediate_AUC.py
# train_convolution_normalization.py
# train_convolution.py
# Untitled.ipynb

# %%
cd models
# Out:
# /home/ak4966/MRI-Alek/models

# %%
import alexnet

# %%
cd ..
# Out:
# /home/ak4966/MRI-Alek

# %%
ls
# Out:
# build_aggregating_validation.py
# build_testing_set_clean.py*
# build_testing_set_save_patientID_no_aggregation.py*
# build_testing_set_save_patientID.py
# build_training_set_clean.py*
# build_training_set_normalization.py
# build_training_set.py
# data_set.py
# group_data.py
# models/
# mri_models_convnet.ipynb
# organize_data.py
# __pycache__/
# pytorch_train.py*
# README.md
# Running alexnet.ipynb
# Testing alexnet.ipynb
# testing_model_aggregating_normalization.py
# testing_model_aggregating.py
# testing_model_all_modalities.py
# testing_model.py
# train_convolution_intermediate_AUC.py
# train_convolution_normalization.py
# train_convolution.py

# %%
build_training_set_clean.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ce97c492c278> in <module>()
# ----> 1 build_training_set_clean.py
#
# NameError: name 'build_training_set_clean' is not defined

# %%
python3 build_testing_set_clean.py
# Out:
#   File "<ipython-input-12-b299d14df9b9>", line 1
#     python3 build_testing_set_clean.py
#                                   ^
# SyntaxError: invalid syntax

# %%
python3 build_testing_set_clean
# Out:
#   File "<ipython-input-13-7e1125508408>", line 1
#     python3 build_testing_set_clean
#                                   ^
# SyntaxError: invalid syntax

# %%
build_testing_set_clean.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-aa6dcc42ad66> in <module>()
# ----> 1 build_testing_set_clean.py
#
# NameError: name 'build_testing_set_clean' is not defined

# %%
ls
# Out:
# build_aggregating_validation.py
# build_testing_set_clean.py*
# build_testing_set_save_patientID_no_aggregation.py*
# build_testing_set_save_patientID.py
# build_training_set_clean.py*
# build_training_set_normalization.py
# build_training_set.py
# data_set.py
# group_data.py
# models/
# mri_models_convnet.ipynb
# organize_data.py
# __pycache__/
# pytorch_train.py*
# README.md
# Running alexnet.ipynb
# Testing alexnet.ipynb
# testing_model_aggregating_normalization.py
# testing_model_aggregating.py
# testing_model_all_modalities.py
# testing_model.py
# train_convolution_intermediate_AUC.py
# train_convolution_normalization.py
# train_convolution.py

# %%
cd models
# Out:
# /home/ak4966/MRI-Alek/models

# %%
import alexnet

# %%
cd ..
# Out:
# /home/ak4966/MRI-Alek

# %%
alexnet.main();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-f9fe6c90eab0> in <module>()
# ----> 1 alexnet.main();
#
# AttributeError: module 'alexnet' has no attribute 'main'

# %%
import build_testing_set_clean
# Out:
#   File "/home/ak4966/MRI-Alek/build_testing_set_clean.py", line 20
#     dataset_type_list = ['testing']
#                     ^
# IndentationError: expected an indented block

# %%
import build_testing_set_clean

# %%
build_testing_set_clean.main(_);
# Out:
# type: T1
# dataset group: testing
# /data/ak4966/MRI/data/new_data//T1_testing/test_TCGA-06-0238_20051204_GBM.np.pkl
# num pts 0
# patient, TCGA-06-0238 is of type: WT
# patient data of shape: (512, 512, 42)
# added 41 new slices and data is now of size: (43, 65536) (43, 3)
# /data/ak4966/MRI/data/new_data//T1_testing/test_TCGA-14-0790_19981707_GBM.np.pkl
# num pts 42
# patient, TCGA-14-0790 is of type: WT
# patient data of shape: (512, 512, 25)
# added 24 new slices and data is now of size: (68, 65536) (68, 3)
# /data/ak4966/MRI/data/new_data//T1_testing/test_TCGA-DU-A5TR_19972607_LGG.np.pkl
# num pts 67
# patient, TCGA-DU-A5TR is of type: Mutant
# patient data of shape: (512, 512, 38)
# added 37 new slices and data is now of size: (106, 65536) (106, 3)
# /data/ak4966/MRI/data/new_data//T1_testing/test_TCGA-12-3648_20003008_GBM.np.pkl
# num pts 105
# patient  TCGA-12-3648 in the CSV file.
# /data/ak4966/MRI/data/new_data//T1_testing/test_TCGA-DU-6410_19952812_LGG.np.pkl
# ...

# %%
import build_testing_set_clean

# %%
import build_testing_set_clean

# %%
import build_training_set_clean
# Out:
#   File "/home/ak4966/MRI-Alek/build_training_set_clean.py", line 23
#     target_dir = '/data/ak4966/MRI/data/pickle_files
#                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
import build_training_set_clean

# %%
build_training_set_clean.main(_);
# Out:
# type: T1
# dataset group: train
# /data/ak4966/MRI/data/new_data//T1_training/train/test_TCGA-DU-A5TP_19971406_LGG.np.pkl
# num pts 0
# patient, TCGA-DU-A5TP is of type: Mutant
# patient data of shape: (512, 512, 38)
# added 37 new slices and data is now of size: (39, 65536) (39, 3)
# /data/ak4966/MRI/data/new_data//T1_training/train/test_TCGA-DU-7299_19911704_LGG.np.pkl
# num pts 38
# patient  TCGA-DU-7299 in the CSV file.
# /data/ak4966/MRI/data/new_data//T1_training/train/test_TCGA-12-0773_19971401_GBM.np.pkl
# num pts 38
# patient  TCGA-12-0773 in the CSV file.
# /data/ak4966/MRI/data/new_data//T1_training/train/test_TCGA-06-0127_20000703_GBM.np.pkl
# num pts 38
# patient, TCGA-06-0127 is of type: WT
# patient data of shape: (256, 256, 50)
# added 49 new slices and data is now of size: (89, 65536) (89, 3)
# /data/ak4966/MRI/data/new_data//T1_training/train/test_TCGA-02-0009_19971406_GBM.np.pkl_extra
# num pts 88
# patient, TCGA-02-0009 is of type: WT
# ...

# %%
cd
# Out:
# /home/ak4966

# %%
cd
